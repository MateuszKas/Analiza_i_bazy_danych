# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os as os

# %%
i=0
data={}
for i in range(10): 
    data[i]= pd.read_csv("dataframe"+str(i)+".csv")
    data[i]=pd.DataFrame(data[i])
    i+=1
data[3]
# Out:
#    Unnamed: 0   Agnostic (not sure if there is a God)   \
# 0           0                                     7980
#
#     Atheist (do not believe in God)    Bahai (VOL)    Buddhist   \
# 0                               4921            133        3990
#
#     Christian (VOL)    Christian Scientists (VOL)    Deist (VOL)   \
# 0               6650                           133            266
#
#     Don’t know/Refused (VOL)   \
# 0                        1862
#
#     Eclectic, a bit of everything, own beliefs (VOL)   ...  \
# 0                                                133   ...
#
#     Rastafarian (VOL)    Religious science (VOL)    Roman Catholic   \
# 0                  133                        133             97356
#
#     Spiritual but not religious (VOL)    Spiritualist (VOL)   \
# 0                                  665                   133
#
#     Theosophy (VOL)    Unitarian (Universalist) (VOL)   \
# 0                133                              1330
#
# ...

# %%
list_=[]
f = open("file.txt")
list_ = f.read().split("|")
f.close()

# %%
j=0
for j in range(10):
    data[j].T.plot(kind='bar')
    plt.xlabel(list_[j])
